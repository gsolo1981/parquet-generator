# %%
# %%
import pandas as pd

# %%
# Leer el archivo parquet (ajusta el nombre del archivo)
filename = "vehicles_20250725_103100.parquet"  
df = pd.read_parquet(filename)

# %%
# Información básica del DataFrame
print(f"Registros: {len(df)}")
print(f"Columnas: {len(df.columns)}")
print(f"Tamaño: {df.shape}")

# %%
# Mostrar las columnas
print("Columnas disponibles:")
print(df.columns.tolist())

# %%
# Mostrar tipos de datos
print("Tipos de datos:")
print(df.dtypes)

# %%
# Mostrar primeras filas
print("Primeras 10 filas:")
df.head(10)

# %%
# Mostrar información estadística básica
df.describe()

# %%
# Ver el DataFrame completo (opcional - si no es muy grande)
df
# Out:
# Registros: 351060
# Columnas: 17
# Tamaño: (351060, 17)
# Columnas disponibles:
# ['id', 'account_id', 'make', 'year', 'color', 'label', 'model', 'domain', 'subtype', 'engine_number', 'chassis_number', 'mileage', 'latitude', 'longitude', 'things', 'location_datetime', 'created_datetime']
# Tipos de datos:
# id                           object
# account_id                   object
# make                         object
# year                        float64
# color                        object
# label                        object
# model                        object
# domain                       object
# subtype                      object
# engine_number                object
# chassis_number               object
# mileage                     float64
# latitude                    float64
# longitude                   float64
# things                       object
# location_datetime    datetime64[ns]
# created_datetime     datetime64[ns]
# dtype: object
# Primeras 10 filas:
# ...
